# %% [markdown]
# the package swmmio and pyswmm can work together.

# %%
import swmmio
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
model = swmmio.Model("Example1_drainage.inp")

# %%
model.summary
# Out:
# {'num_subcatchments': 8,
#  'num_conduits': 13,
#  'num_junctions': 13,
#  'num_outfalls': 1,
#  'num_raingages': 1,
#  'catchment_area': 71,
#  'mean_subcatchment_slope': 0.010000000000000002,
#  'total_conduit_length': 4300,
#  'invert_range': 35}

# %% [markdown]
# the 'swmmio' is often used to visualize the model parameters.

# %%
# get the data related to links
model.links.dataframe
# Out:
#      InletNode OutletNode  Length  Roughness  InOffset  OutOffset  InitFlow  \
# Name
# 1            9         10     400       0.01         0          0         0
# 4           19         20     200       0.01         0          0         0
# 5           20         21     200       0.01         0          0         0
# 6           10         21     400       0.01         0          1         0
# 7           21         22     300       0.01         1          1         0
# 8           22         16     300       0.01         0          0         0
# 10          17         18     400       0.01         0          0         0
# 11          13         14     400       0.01         0          0         0
# 12          14         15     400       0.01         0          0         0
# 13          15         16     400       0.01         0          0         0
# 14          23         24     400       0.01         0          0         0
# 15          16         24     100       0.01         0          0         0
# 16          24         17     400       0.01         0          0         0
#
#       MaxFlow     Shape  Geom1  Geom2  Geom3  Geom4  Barrels  \
# Name
# 1           0  CIRCULAR    1.5      0      0      0        1
# 4           0  CIRCULAR    1.0      0      0      0        1
# 5           0  CIRCULAR    1.0      0      0      0        1
# 6           0  CIRCULAR    1.0      0      0      0        1
# 7           0  CIRCULAR    2.0      0      0      0        1
# 8           0  CIRCULAR    2.0      0      0      0        1
# 10          0  CIRCULAR    2.0      0      0      0        1
# 11          0  CIRCULAR    1.5      0      0      0        1
# 12          0  CIRCULAR    1.5      0      0      0        1
# 13          0  CIRCULAR    1.5      0      0      0        1
# 14          0  CIRCULAR    1.0      0      0      0        1
# 15          0  CIRCULAR    2.0      0      0      0        1
# 16          0  CIRCULAR    2.0      0      0      0        1
#
#                                                            coords
# Name
# 1                         [(4042.11, 9600.0), (4105.26, 6947.37)]
# 4                        [(7768.42, 6736.84), (5957.89, 6589.47)]
# 5                        [(5957.89, 6589.47), (4926.32, 6105.26)]
# 6                        [(4105.26, 6947.37), (4926.32, 6105.26)]
# 7                        [(4926.32, 6105.26), (4421.05, 4715.79)]
# 8                        [(4421.05, 4715.79), (4821.05, 3326.32)]
# 10    [(6252.63, 2147.37), (6673.68, 1368.42), (6631.58, 505.26)]
# 11                       [(2336.84, 4357.89), (3157.89, 4294.74)]
# 12                       [(3157.89, 4294.74), (3221.05, 3242.11)]
# 13                       [(3221.05, 3242.11), (4821.05, 3326.32)]
# 14                       [(6484.21, 3978.95), (5389.47, 3031.58)]
# 15                       [(4821.05, 3326.32), (5389.47, 3031.58)]
# 16                       [(5389.47, 3031.58), (6252.63, 2147.37)]

# %%
model.subcatchments.dataframe
# Out:
#      Raingage  Outlet  Area  PercImperv  Width  PercSlope  CurbLength  \
# Name
# 1         RG1       9    10          50    500       0.01           0
# 2         RG1      10    10          50    500       0.01           0
# 3         RG1      13     5          50    500       0.01           0
# 4         RG1      22     5          50    500       0.01           0
# 5         RG1      15    15          50    500       0.01           0
# 6         RG1      23    12          10    500       0.01           0
# 7         RG1      19     4          10    500       0.01           0
# 8         RG1      18    10          10    500       0.01           0
#
#       N-Imperv  N-Perv  S-Imperv  S-Perv  PctZero RouteTo  \
# Name
# 1        0.001     0.1      0.05    0.05       25  OUTLET
# 2        0.001     0.1      0.05    0.05       25  OUTLET
# 3        0.001     0.1      0.05    0.05       25  OUTLET
# 4        0.001     0.1      0.05    0.05       25  OUTLET
# 5        0.001     0.1      0.05    0.05       25  OUTLET
# 6        0.001     0.1      0.05    0.05       25  OUTLET
# 7        0.001     0.1      0.05    0.05       25  OUTLET
# 8        0.001     0.1      0.05    0.05       25  OUTLET
#
#                                                                                                                                                                                                        coords
# Name
# 1                                                 [(3936.84, 6905.26), (3494.74, 6252.63), (273.68, 6336.84), (252.63, 8526.32), (463.16, 9200.0), (1157.89, 9726.32), (4000.0, 9705.26), (3936.84, 6905.26)]
# 2                                                                   [(7600.0, 9663.16), (7705.26, 6736.84), (5915.79, 6694.74), (4926.32, 6294.74), (4189.47, 7200.0), (4126.32, 9621.05), (7600.0, 9663.16)]
# 3                                                                    [(2357.89, 6021.05), (2400.0, 4336.84), (3031.58, 4252.63), (2989.47, 3389.47), (315.79, 3410.53), (294.74, 6000.0), (2357.89, 6021.05)]
# 4     [(3473.68, 6105.26), (3915.79, 6421.05), (4168.42, 6694.74), (4463.16, 6463.16), (4821.05, 6063.16), (4400.0, 5263.16), (4357.89, 4442.11), (4547.37, 3705.26), (4000.0, 3431.58), (3326.32, 3368.42...
# 5     [(2568.42, 3200.0), (4905.26, 3136.84), (5221.05, 2842.11), (5747.37, 2421.05), (6463.16, 1578.95), (6610.53, 968.42), (6589.47, 505.26), (1305.26, 484.21), (968.42, 336.84), (315.79, 778.95), (31...
# 6     [(9052.63, 4147.37), (7894.74, 4189.47), (6442.11, 4105.26), (5915.79, 3642.11), (5326.32, 3221.05), (4631.58, 4231.58), (4568.42, 5010.53), (4884.21, 5768.42), (5368.42, 6294.74), (6042.11, 6568....
# 7                                                                 [(8736.84, 9642.11), (9010.53, 9389.47), (9010.53, 8631.58), (9052.63, 6778.95), (7789.47, 6800.0), (7726.32, 9642.11), (8736.84, 9642.11)]
# 8     [(9073.68, 2063.16), (9052.63, 778.95), (8505.26, 336.84), (7431.58, 315.79), (7410.53, 484.21), (6842.11, 505.26), (6842.11, 589.47), (6821.05, 1178.95), (6547.37, 1831.58), (6147.37, 2378.95), (...

# %%
model.inp.raingages
# Out:
#        RainType TimeIntrvl  SnowCatch  DataSource DataSourceName
# Name
# RG1   INTENSITY       1:00        1.0  TIMESERIES            TS1

# %%
# here is the exsiting outfalls DataFrame
model.inp.outfalls
# Out:
#       InvertElev OutfallType StageOrTimeseries
# Name
# 18           975        FREE                NO

# %%
model.nodes.dataframe
# Out:
#       InvertElev  MaxDepth  InitDepth  SurchargeDepth  PondedArea OutfallType  \
# Name
# 9           1000       3.0        0.0             0.0         0.0         NaN
# 10           995       3.0        0.0             0.0         0.0         NaN
# 13           995       3.0        0.0             0.0         0.0         NaN
# 14           990       3.0        0.0             0.0         0.0         NaN
# 15           987       3.0        0.0             0.0         0.0         NaN
# 16           985       3.0        0.0             0.0         0.0         NaN
# 17           980       3.0        0.0             0.0         0.0         NaN
# 19          1010       3.0        0.0             0.0         0.0         NaN
# 20          1005       3.0        0.0             0.0         0.0         NaN
# 21           990       3.0        0.0             0.0         0.0         NaN
# 22           987       3.0        0.0             0.0         0.0         NaN
# 23           990       3.0        0.0             0.0         0.0         NaN
# 24           984       3.0        0.0             0.0         0.0         NaN
# 18           975       NaN        NaN             NaN         NaN        FREE
#
#      StageOrTimeseries                coords
# Name
# 9                  NaN   [(4042.11, 9600.0)]
# 10                 NaN  [(4105.26, 6947.37)]
# 13                 NaN  [(2336.84, 4357.89)]
# 14                 NaN  [(3157.89, 4294.74)]
# 15                 NaN  [(3221.05, 3242.11)]
# 16                 NaN  [(4821.05, 3326.32)]
# 17                 NaN  [(6252.63, 2147.37)]
# 19                 NaN  [(7768.42, 6736.84)]
# 20                 NaN  [(5957.89, 6589.47)]
# 21                 NaN  [(4926.32, 6105.26)]
# 22                 NaN  [(4421.05, 4715.79)]
# 23                 NaN  [(6484.21, 3978.95)]
# 24                 NaN  [(5389.47, 3031.58)]
# 18                  NO   [(6631.58, 505.26)]

# %%
model.inp.subcatchments
# Out:
#      Raingage  Outlet  Area  PercImperv  Width  PercSlope  CurbLength
# Name
# 1         RG1       9    10          50    500       0.01           0
# 2         RG1      10    10          50    500       0.01           0
# 3         RG1      13     5          50    500       0.01           0
# 4         RG1      22     5          50    500       0.01           0
# 5         RG1      15    15          50    500       0.01           0
# 6         RG1      23    12          10    500       0.01           0
# 7         RG1      19     4          10    500       0.01           0
# 8         RG1      18    10          10    500       0.01           0

# %%
swmmio.draw_model(model, px_width=200)
# Out:
# <PIL.Image.Image image mode=RGB size=400x669>

# %% [markdown]
# The following codes show how the swmmio can be used to interact with the pyswmm, for conducting the hydraulic simulation

# %%
import pyswmm

# %%
link_flows = dict()

# Run simulation PySWMM  
with pyswmm.Simulation(model.inp.path) as sim:

  # get link ids  
  link_ids = model.inp.conduits.index
  
  for step in sim:
    # store each link's flow in a dictionary 
    link_flows[sim.current_time] = {
      link_id: pyswmm.Links(sim)[link_id].flow 
      for link_id in link_ids
  }

pd.DataFrame(link_flows).T.plot(title='Link Flows')
# Out:
# <Axes: title={'center': 'Link Flows'}>

# %%
flow_results = pd.DataFrame(link_flows)

# %%
flow_results.T
# Out:
#                             1    4    5         6         7         8  \
# 1998-01-01 00:01:00  0.000000  0.0  0.0  0.000000  0.000000  0.000000
# 1998-01-01 00:02:00  0.000000  0.0  0.0  0.000000  0.000000  0.000000
# 1998-01-01 00:03:00  0.000000  0.0  0.0  0.000000  0.000000  0.000000
# 1998-01-01 00:04:00  0.000000  0.0  0.0  0.000000  0.000000  0.000000
# 1998-01-01 00:05:00  0.000000  0.0  0.0  0.000000  0.000000  0.000000
# ...                       ...  ...  ...       ...       ...       ...
# 1998-01-02 11:55:00  0.001272  0.0  0.0  0.002584  0.002669  0.003004
# 1998-01-02 11:56:00  0.001264  0.0  0.0  0.002567  0.002651  0.002983
# 1998-01-02 11:57:00  0.001256  0.0  0.0  0.002550  0.002634  0.002964
# 1998-01-02 11:58:00  0.001247  0.0  0.0  0.002533  0.002616  0.002944
# 1998-01-02 11:59:00  0.001239  0.0  0.0  0.002517  0.002599  0.002924
#
#                            10        11        12        13        14  \
# 1998-01-01 00:01:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 1998-01-01 00:02:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 1998-01-01 00:03:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 1998-01-01 00:04:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 1998-01-01 00:05:00  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                       ...       ...       ...       ...       ...
# 1998-01-02 11:55:00  0.007159  0.000247  0.000272  0.003630  0.000043
# 1998-01-02 11:56:00  0.007111  0.000245  0.000270  0.003607  0.000043
# 1998-01-02 11:57:00  0.007064  0.000243  0.000268  0.003584  0.000042
# 1998-01-02 11:58:00  0.007018  0.000242  0.000266  0.003561  0.000042
# 1998-01-02 11:59:00  0.006972  0.000240  0.000264  0.003538  0.000042
#
#                            15        16
# 1998-01-01 00:01:00  0.000000  0.000000
# 1998-01-01 00:02:00  0.000000  0.000000
# 1998-01-01 00:03:00  0.000000  0.000000
# 1998-01-01 00:04:00  0.000000  0.000000
# 1998-01-01 00:05:00  0.000000  0.000000
# ...                       ...       ...
# 1998-01-02 11:55:00  0.006687  0.006949
# 1998-01-02 11:56:00  0.006644  0.006904
# 1998-01-02 11:57:00  0.006600  0.006858
# 1998-01-02 11:58:00  0.006557  0.006814
# 1998-01-02 11:59:00  0.006515  0.006769
#
# [2159 rows x 13 columns]
